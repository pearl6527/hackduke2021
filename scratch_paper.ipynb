# %%
import pandas as pd
import numpy as np

# %%
data_2014 = pd.read_csv("mental_health_tech_2014.csv")
data_2016 = pd.read_csv("mental_health_tech_2016.csv")

# %%
data_2014
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44    male   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46  female   United States    NC            No
# 1258  2016-02-01 23:04:31   25    male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
data_2014["work_interfere"] = data_2014["work_interfere"].fillna("NA")

# %%
temp = data_2014[["benefits", "mental_health_consequence", "phys_health_consequence"]]

# %%
pd.crosstab(temp["benefits"], temp["mental_health_consequence"], normalize='index')
# Out:
# mental_health_consequence     Maybe        No       Yes
# benefits
# Don't know                 0.379902  0.431373  0.188725
# No                         0.328877  0.371658  0.299465
# Yes                        0.417191  0.366876  0.215933

# %%
pd.crosstab(temp["benefits"], temp["phys_health_consequence"], normalize='index')
# Out:
# phys_health_consequence     Maybe        No       Yes
# benefits
# Don't know               0.176471  0.781863  0.041667
# No                       0.267380  0.668449  0.064171
# Yes                      0.211740  0.746331  0.041929

# %%
data_1 = data_2014[["no_employees", "work_interfere", "Gender"]].dropna()

# %%
data_2 = data_2014[["Gender", "work_interfere"]].dropna()

# %%
data_3 = data_2014[["Gender", "work_interfere", "benefits"]]

# %%
data_4 = data_2014[["benefits", "work_interfere"]].dropna()

# %%
pd.crosstab(data_4["benefits"], data_4["work_interfere"])
# Out:
# work_interfere   NA  Never  Often  Rarely  Sometimes
# benefits
# Don't know      114     86     33      38        137
# No               79     52     53      49        141
# Yes              71     75     58      86        187

# %%
gender_work = pd.crosstab(data_3["work_interfere"], data_3["Gender"])

# %%
data_3["benefits"] = data_3["benefits"].replace("Don't know", "No")
# Out:
# <ipython-input-219-66efdb461770>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_3["benefits"] = data_3["benefits"].replace("Don't know", "No")

# %%
data_3
# Out:
#       Gender work_interfere benefits
# 0     female          Often      Yes
# 1       male         Rarely       No
# 2       male         Rarely       No
# 3       male          Often       No
# 4       male          Never      Yes
# ...      ...            ...      ...
# 1254    male             NA       No
# 1255    male          Often      Yes
# 1256    male      Sometimes      Yes
# 1257  female             NA       No
# 1258    male      Sometimes      Yes
#
# [1259 rows x 3 columns]

# %%
gender_work_ben = pd.crosstab(data_3["work_interfere"], [data_3["Gender"], data_3["benefits"]])

# %%
gender_work_ben
# Out:
# Gender         female     male      other
# benefits           No Yes   No  Yes    No Yes
# work_interfere
# NA                 27   9  166   61     0   1
# Never              11  14  127   60     0   1
# Often              15  19   69   36     2   3
# Rarely             14  30   72   54     1   2
# Sometimes          52  56  220  129     6   2

# %%
gender_work
# Out:
# Gender          female  male  other
# work_interfere
# NA                  36   227      1
# Never               25   187      1
# Often               34   105      5
# Rarely              44   126      3
# Sometimes          108   349      8

# %%
type(gender_work)
# Out:
# pandas.core.frame.DataFrame

# %%
gender_work_ben.to_csv('gender_work_ben.csv', encoding='utf-8')

# %%
pd.crosstab(data_2["Gender"], data_2["work_interfere"], normalize='index')
# Out:
# work_interfere        NA     Never     Often    Rarely  Sometimes
# Gender
# female          0.145749  0.101215  0.137652  0.178138   0.437247
# male            0.228370  0.188129  0.105634  0.126761   0.351107
# other           0.055556  0.055556  0.277778  0.166667   0.444444

# %%
pd.crosstab(data_1["no_employees"], [data_1["Gender"], data_1["work_interfere"]], normalize='index')
# Out:
# Gender            female                                              male  \
# work_interfere        NA     Never     Often    Rarely Sometimes        NA
# no_employees
# 1-5             0.006173  0.006173  0.043210  0.024691  0.098765  0.117284
# 100-500         0.034091  0.039773  0.028409  0.034091  0.119318  0.170455
# 26-100          0.017301  0.013841  0.020761  0.020761  0.110727  0.186851
# 500-1000        0.066667  0.083333  0.000000  0.083333  0.133333  0.200000
# 6-25            0.031034  0.003448  0.024138  0.027586  0.048276  0.213793
# More than 1000  0.039007  0.024823  0.031915  0.053191  0.060284  0.177305
#
# Gender                                                    other            \
# work_interfere     Never     Often    Rarely Sometimes       NA     Never
# no_employees
# 1-5             0.135802  0.098765  0.111111  0.333333  0.00000  0.000000
# 100-500         0.130682  0.056818  0.125000  0.250000  0.00000  0.000000
# ...

# %%
data_2014["benefits"]
# Out:
# 0              Yes
# 1       Don't know
# 2               No
# 3               No
# 4              Yes
#            ...
# 1254            No
# 1255           Yes
# 1256           Yes
# 1257            No
# 1258           Yes
# Name: benefits, Length: 1259, dtype: object

# %%
# data_2016

# %%
print()
